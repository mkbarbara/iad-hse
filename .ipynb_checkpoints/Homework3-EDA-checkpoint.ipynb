# %% [markdown]
# ## Домашнее задание 3 (10 баллов)

# %% [markdown]
# ### О задании

# %% [markdown]
# В этом домашнем задании вы получите опыт подготовки данных и EDA (Exploratory Data Analysis), приблизившись к реальной работе с данными с помощью уже знакомых вам инструментов: numpy, pandas, matplotlib и seaborn.

# %% [markdown]
# Вы будет работать с задачей кредитного скоринга (оценка надёжности клиента). Предоставляются данные о 1000 клиентов, про которых известно около 20 признаков и положительная или отрицательная оценка в качестве кредитуемого. Эти данные нужно будет подготовить, исследовать (в том числе с помощью средств визуализации) и даже попробовать предложить какую-нибудь формулу для условной оценки надёжности клиентов исходя из предоставленных данных. Описание данных:
# https://www.rdocumentation.org/packages/evtree/versions/1.0-8/topics/GermanCredit
#
# Каждый построенный график необходимо красиво оформить - для этого требуется как минимум указать его название, а также отметить, что изображено по каждой из осей.
# Также по каждому графику ожидается небольшой комментарий с выводами.
#
# *Функции, которые могут пригодиться при оформлении графиков: `.show()`, `.title()`, `.xlabel()`, `.ylabel()`*

# %%
import pandas as pd

# %% [markdown]
# ### Задание 1 (0.0 балла)

# %% [markdown]
# Прочитайте средствами pandas файл с данными по ссылке https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2022/homeworks/hw03-EDA/german_credit.csv. Выведите базовое представление таблицы (первые 5 и последние 5 строк, размер).

# %%
# your code here
data = pd.read_csv('https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2022/homeworks/hw03-EDA/german_credit.csv')

# %%
data.head()
# Out:
#                 status  duration                               credit_history  \
# 0  no checking account        18      all credits at this bank paid back duly
# 1  no checking account         9      all credits at this bank paid back duly
# 2           ... < 0 DM        12  no credits taken/all credits paid back duly
# 3  no checking account        12      all credits at this bank paid back duly
# 4  no checking account        12      all credits at this bank paid back duly
#
#       purpose  amount                     savings employment_duration  \
# 0  car (used)    1049  unknown/no savings account              < 1 yr
# 1      others    2799  unknown/no savings account    1 <= ... < 4 yrs
# 2  retraining     841               ... <  100 DM    4 <= ... < 7 yrs
# 3      others    2122  unknown/no savings account    1 <= ... < 4 yrs
# 4      others    2171  unknown/no savings account    1 <= ... < 4 yrs
#
# ...

# %%
data.tail()
# Out:
#                                          status  duration  \
# 995                         no checking account        24
# 996                         no checking account        24
# 997  ... >= 200 DM / salary for at least 1 year        21
# 998                                  ... < 0 DM        12
# 999                         no checking account        30
#
#                                   credit_history              purpose  amount  \
# 995  no credits taken/all credits paid back duly  furniture/equipment    1987
# 996  no credits taken/all credits paid back duly               others    2303
# 997      all credits at this bank paid back duly               others   12680
# 998  no credits taken/all credits paid back duly  furniture/equipment    6468
# 999  no credits taken/all credits paid back duly           car (used)    6350
#
#                         savings employment_duration installment_rate  \
# 995  unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# ...

# %% [markdown]
# ### Задание 2 (0.5 балла)

# %% [markdown]
# Определите, есть ли пропуски в данных. Разделите признаки на количественные, бинарные, порядковые и категориальные.

# %%
data.dtypes
# Out:
# status                     object
# duration                    int64
# credit_history             object
# purpose                    object
# amount                      int64
# savings                    object
# employment_duration        object
# installment_rate           object
# personal_status_sex        object
# other_debtors              object
# present_residence          object
# property                   object
# age                         int64
# other_installment_plans    object
# housing                    object
# number_credits             object
# job                        object
# people_liable              object
# telephone                  object
# foreign_worker             object
# credit_risk                object
# dtype: object

# %% [markdown]
# Количественные: duration, amount,

# %%
data.isnull().sum()
# Out:
# status                     0
# duration                   0
# credit_history             0
# purpose                    0
# amount                     0
# savings                    0
# employment_duration        0
# installment_rate           0
# personal_status_sex        0
# other_debtors              0
# present_residence          0
# property                   0
# age                        0
# other_installment_plans    0
# housing                    0
# number_credits             0
# job                        0
# people_liable              0
# telephone                  0
# foreign_worker             0
# credit_risk                0
# dtype: int64

# %% [markdown]
# Нулевых значений нет

# %% [markdown]
# ### Задание 3 (0.5 балла)

# %% [markdown]
# Выведите среднюю сумму кредита (колонка amount) в каждой категории (колонка purpose), воспользовавшись методом groupby.

# %%
data.groupby('purpose')['amount'].mean()
# Out:
# purpose
# business               8209.333333
# car (new)              5370.223301
# car (used)             3066.983425
# domestic appliances    2728.090909
# furniture/equipment    2487.685714
# others                 3062.948718
# radio/television       1498.000000
# repairs                3180.400000
# retraining             4158.041237
# vacation               1205.888889
# Name: amount, dtype: float64

# %% [markdown]
# ### Задание 4 (0.5 балла)

# %% [markdown]
# Какой процент клиентов моложе 30 лет (колонка age) снимает жилье (колонка housing)? А какой процент клиентов старше 40 лет снимает жилье?

# %% [markdown]
# Процент клиентов моложе 30 лет снимает жилье:

# %%
data.loc[(data['age'] < 30) & (data['housing'] == 'rent'), 'status'].count()/len(data)
# Out:
# 0.246

# %% [markdown]
# Процент клиентов старше 40 лет снимает жилье:

# %%
data.loc[(data['age'] > 40) & (data['housing'] == 'rent'), 'status'].count()/len(data)
# Out:
# 0.185

# %% [markdown]
# ### Задание 5 (0.5 балла)

# %% [markdown]
#  У скольких иностранцев (foreign_worker) число кредитов (number_credits) больше 3?

# %%
data.loc[(((data['number_credits'] == '4-5') | (data['number_credits'] == '>=6')) & (data['foreign_worker'] == 'yes')), 'foreign_worker'].count()
# Out:
# 1

# %% [markdown]
# ### Задание 6 (1 балл)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Используя numpy и matplotlib, начнём с тренировки: постройте график функций $sin(x)$ и $cos(x)$ от $-\pi$ до $\pi$ из 100 точек c легендой и сеткой. Используйте для линий разные цвета, одна из них пусть будет пунктирной. Результат в этом и следующих заданиях на построение графиков должен получиться примерно как на картинке. Содержание подписей не должно обязательно совпадать, однако осмысленные подписи должны присутствовать на графиках.

# %%
plt.figure(figsize=(8,5))

x = np.arange(-3, 3, 0.06)
y = np.sin(x)
z = np.cos(x)
plt.plot(x, y, label='y=sin(x)')
plt.plot(x, z, label='Y=cos(x)', ls='--')
plt.xlabel('number')

plt.legend()
plt.show()

# %% [markdown]
# ### Задание 7 (1 балл)

# %% [markdown]
# Рассмотрим сравнительное количество положительных и отрицательных кейсов в зависимости от размера текущего счёта. Постройте зеркальные горизонтальные гистограммы.

# %%
fig, axes = plt.subplots(figsize=(10,5), facecolor='#ffffff', ncols=2)

data_bad_risk = data.loc[data['credit_risk'] == 'bad']
data_good_risk = data.loc[data['credit_risk'] == 'good']
data_bad_risk['status'].value_counts().sort_index().plot(kind='barh', ax=axes.ravel()[1], color='red')
data_good_risk['status'].value_counts().sort_index().plot(kind='barh', ax=axes.ravel()[0], color='green')

axes[1].set_title('Bad Risk')
axes[0].set_title('Good Risk')
axes[0].invert_xaxis()
axes[1].yaxis.tick_right()
axes[1].set_xlim(right=350)
fig.suptitle('Status of checking acount')
# Out:
# Text(0.5, 0.98, 'Status of checking acount')

# %% [markdown]
# ### Задание 8  (0.5 балла)

# %%
import seaborn as sns

# %% [markdown]
# Теперь постройте гистограмму для сравнения количества положительных и отрицательных кейсов в зависимости от размера сберегательного счёта с помощью seaborn. Какой способ вам больше нравится с точки зрения трудоёмкости написания кода? А с точки зрения восприятия результата?

# %%
fig, ax1 = plt.subplots(figsize=(10,6))
sns.countplot(data=data, x='savings', hue='credit_risk',palette=["green", "red"], ax=ax1)
# Out:
# <AxesSubplot:xlabel='savings', ylabel='count'>

# %% [markdown]
# ### Задание 9  (1 балл)

# %% [markdown]
# seaborn легко позволяет добавить ещё больше информации на один график. Для каждого размера сберегательного счёта мы можем оценить не только количество положительных и отрицательных кейсов, но и их распределение по возрасту, например. Постройте подходящую для этого визуализацию.

# %%
fig, ax1 = plt.subplots(figsize=(14,7))
sns.violinplot(data=data, x='savings', y='age',hue='credit_risk',palette=["green", "red"], ax=ax1, split=True)
# Out:
# <AxesSubplot:xlabel='savings', ylabel='age'>

# %% [markdown]
# ### Задание 10  (0.5 балла)

# %% [markdown]
# Заканчивая с гистограммами, посмотрим на распределение положительных и отрицательных кейсов по возрастам, разместив их друг над другом. Добавим распределение всех взятых кредитов.

# %%
import matplotlib.ticker as ticker

# %%
fig, ax = plt.subplots(3, figsize=(5,7))
sns.histplot(data=data_good_risk, x='age', color="green", ax=ax[0], label="Good credits age distribution")
sns.histplot(data=data_bad_risk, x='age', color="red", ax=ax[1], label="Bad credits age distribution")
sns.histplot(data=data, x='age', color="blue", ax=ax[2], label="Overall age distribution")

ax[0].set_ylim(0,200)
ax[1].set_ylim(0,200)
ax[2].set_ylim(0,200)

plt.rcParams['patch.edgecolor'] = 'none'

lines = []
labels = []

for ax in fig.axes:
    axLine, axLabel = ax.get_legend_handles_labels()
    lines.extend(axLine)
    labels.extend(axLabel)

    
fig.legend(lines, labels,loc='upper right', bbox_to_anchor=(1, 0.9))

# %% [markdown]
# ### Задание 11  (0.5 балла)

# %% [markdown]
# Не менее полезной иногда может быть диаграмма рассеяния. Постройте такую диаграмму с продолжительностью и размерами кредитов в качестве осей. Обозначьте положительные и отрицательные кейсы разными цветами.

# %%
fig, ax = plt.subplots(figsize=(14,7))
sns.scatterplot(data=data, x = 'amount', y='duration', hue='credit_risk', palette=["green", "red"], legend=False)
ax.set_ylabel('Duration')
ax.set_xlabel('Credit amount')
# Out:
# Text(0.5, 0, 'Credit amount')

# %% [markdown]
# ### Задание 12  (1 балл)

# %% [markdown]
# Продвинемся глубже. Постройте 3D версию диаграммы рассеяния, добавив ось с возрастом.

# %%
from matplotlib.colors import ListedColormap
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection = '3d')

ax.set_xlabel("Credit amount")
ax.set_ylabel("Duration")
ax.set_zlabel("Age")
my_cmap = ListedColormap(sns.color_palette(['red', 'green']).as_hex())
data_for_scatter = data.replace({"credit_risk": {"bad": 0, "good": 1}})['credit_risk']

ax.scatter(data['amount'], data['duration'], data['age'], c=data_for_scatter, cmap = my_cmap)

# %% [markdown]
# ### Задание 13  (0.5 балла)

# %% [markdown]
# Представьте все порядковые и бинарные признаки в виде числовых значений {0, ..., n - 1}, где n это количество значений признака. Избавьтесь от категориальных признаков.

# %%
data_second = data.drop(['purpose', 'property', 'credit_history', 'other_debtors', 'other_installment_plans'], axis=1)
data_second.head()
# Out:
#                 status  duration  amount                     savings  \
# 0  no checking account        18    1049  unknown/no savings account
# 1  no checking account         9    2799  unknown/no savings account
# 2           ... < 0 DM        12     841               ... <  100 DM
# 3  no checking account        12    2122  unknown/no savings account
# 4  no checking account        12    2171  unknown/no savings account
#
#   employment_duration installment_rate                   personal_status_sex  \
# 0              < 1 yr             < 20  female : non-single or male : single
# 1    1 <= ... < 4 yrs   25 <= ... < 35                male : married/widowed
# 2    4 <= ... < 7 yrs   25 <= ... < 35  female : non-single or male : single
# 3    1 <= ... < 4 yrs   20 <= ... < 25                male : married/widowed
# 4    1 <= ... < 4 yrs             < 20                male : married/widowed
#
#   present_residence  age   housing number_credits                        job  \
# ...

# %%
data_second = data_second.replace({"status": {"no checking account": 0, "... < 0 DM": 1, "0<= ... < 200 DM": 2, "... >= 200 DM / salary for at least 1 year": 3},
                                   "savings": {"unknown/no savings account": 0, "... <  100 DM": 1, "100 <= ... <  500 DM": 2, "500 <= ... < 1000 DM": 3, "... >= 1000 DM": 4},
                                   'employment_duration': {"unemployed": 0, "< 1 yr": 1, "1 <= ... < 4 yrs": 2, "4 <= ... < 7 yrs": 3, ">= 7 yrs": 4},
                                   'installment_rate': {"< 20": 0, "20 <= ... < 25": 1, "25 <= ... < 35": 2, ">= 35": 3},
                                   'present_residence': {"< 1 yr": 0, "1 <= ... < 4 yrs": 1, "4 <= ... < 7 yrs": 2, ">= 7 yrs": 3},
                                   'housing': {'own': 0, 'for free': 1, "rent": 2},
                                   'number_credits': {'1': 0, '2-3': 1, '4-5': 2, '>= 6': 3},
                                   'job': {"unemployed/unskilled - non-resident": 0, "unskilled - resident": 1, "skilled employee/official": 2, "manager/self-empl./highly qualif. employee": 3},
                                   'people_liable': {'0 to 2': 0, "3 or more": 1},
                                   'foreign_worker': {'yes': 1, 'no': 0},
                                   'telephone': {'yes (under customer name)': 1, 'no': 0},
                                   'credit_risk': {'good': 1, 'bad': 0},
                                       'personal_status_sex': {'female : non-single or male : single': 0, 'male : married/widowed': 1, 'female : single': 2, 'male : divorced/separated': 3}})
data_second.head()
# Out:
#    status  duration  amount  savings  employment_duration  installment_rate  \
# 0       0        18    1049        0                    1                 0
# 1       0         9    2799        0                    2                 2
# 2       1        12     841        1                    3                 2
# 3       0        12    2122        0                    2                 1
# 4       0        12    2171        0                    2                 0
#
#    personal_status_sex  present_residence  age  housing  number_credits  job  \
# 0                    0                  3   21        1               0    2
# 1                    1                  1   36        1               1    2
# 2                    0                  3   23        1               0    1
# 3                    1                  1   39        1               1    1
# 4                    1                  3   38        2               1    1
#
# ...

# %%
data_second['duration'].max()
# Out:
# 72

# %%
data_second['age'] = np.where((data_second['age'] >= 18) & (data_second['age'] < 30), 0, data_second['age'])
data_second['age'] = np.where((data_second['age'] >= 30) & (data_second['age'] < 40), 1, data_second['age'])
data_second['age'] = np.where((data_second['age'] >= 40) & (data_second['age'] < 50), 2, data_second['age'])
data_second['age'] = np.where((data_second['age'] >= 50) & (data_second['age'] < 60), 3, data_second['age'])
data_second['age'] = np.where((data_second['age'] >= 60) & (data_second['age'] < 70), 4, data_second['age'])
data_second['age'] = np.where((data_second['age'] >= 70) & (data_second['age'] < 80), 5, data_second['age'])
data_second
# Out:
#      status  duration  amount  savings  employment_duration  installment_rate  \
# 0         0        18    1049        0                    1                 0
# 1         0         9    2799        0                    2                 2
# 2         1        12     841        1                    3                 2
# 3         0        12    2122        0                    2                 1
# 4         0        12    2171        0                    2                 0
# ..      ...       ...     ...      ...                  ...               ...
# 995       0        24    1987        0                    2                 2
# 996       0        24    2303        0                    4                 0
# 997       3        21   12680        4                    4                 0
# 998       1        12    6468        4                    0                 2
# 999       0        30    6350        4                    4                 0
#
# ...

# %%
data_second['amount'] = np.where((data_second['amount'] >= 250) & (data_second['amount'] < 1000), 0, data_second['amount'])
data_second['amount'] = np.where((data_second['amount'] >= 1000) & (data_second['amount'] < 5000), 1, data_second['amount'])
data_second['amount'] = np.where((data_second['amount'] >= 5000) & (data_second['amount'] < 10000), 2, data_second['amount'])
data_second['amount'] = np.where((data_second['amount'] >= 10000) & (data_second['amount'] < 20000), 3, data_second['amount'])
data_second
# Out:
#      status  duration  amount  savings  employment_duration  installment_rate  \
# 0         0        18       1        0                    1                 0
# 1         0         9       1        0                    2                 2
# 2         1        12       0        1                    3                 2
# 3         0        12       1        0                    2                 1
# 4         0        12       1        0                    2                 0
# ..      ...       ...     ...      ...                  ...               ...
# 995       0        24       1        0                    2                 2
# 996       0        24       1        0                    4                 0
# 997       3        21       3        4                    4                 0
# 998       1        12       2        4                    0                 2
# 999       0        30       2        4                    4                 0
#
# ...

# %%
data_second['duration'] = np.where((data_second['duration'] >= 0) & (data_second['duration'] < 12), 0, data_second['duration'])
data_second['duration'] = np.where((data_second['duration'] >= 12) & (data_second['duration'] < 24), 1, data_second['duration'])
data_second['duration'] = np.where((data_second['duration'] >= 24) & (data_second['duration'] < 48), 2, data_second['duration'])
data_second['duration'] = np.where((data_second['duration'] >= 48) & (data_second['duration'] < 60), 3, data_second['duration'])
data_second['duration'] = np.where((data_second['duration'] >= 60) & (data_second['duration'] <= 72), 4, data_second['duration'])
data_second
# Out:
#      status  duration  amount  savings  employment_duration  installment_rate  \
# 0         0         1       1        0                    1                 0
# 1         0         0       1        0                    2                 2
# 2         1         1       0        1                    3                 2
# 3         0         1       1        0                    2                 1
# 4         0         1       1        0                    2                 0
# ..      ...       ...     ...      ...                  ...               ...
# 995       0         2       1        0                    2                 2
# 996       0         2       1        0                    4                 0
# 997       3         1       3        4                    4                 0
# 998       1         1       2        4                    0                 2
# 999       0         2       2        4                    4                 0
#
# ...

# %%
sns.heatmap(data_second.corr(),
            cmap='coolwarm',
            annot=True,
            fmt=".2f",
            annot_kws={'size':10},
            cbar=False)
# Out:
# <AxesSubplot:>

# %%
data = data_second.drop(['personal_status_sex', 'present_residence', 'job', 'people_liable', 'telephone'], axis = 1)
sns.heatmap(data.corr(),
            cmap='coolwarm',
            annot=True,
            fmt=".2f",
            annot_kws={'size':10},
            cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Задание 14  (2 балла)

# %% [markdown]
# По результатам предыдущего задания у вас должна получиться таблица, в которой все признаки так или иначе представлены числовыми значениями. Попробуйте придумать на основе проведённых исследований данных какую-нибудь формулу, связывающую целевую переменную с признаками, не используя готовых инструментов машинного обучения. По желанию вы можете исключить ещё какие-то признаки, или, наоборот, сформировать новые на основе имеющихся. Возможно, вы захотите отмасштабировать большие наборы численных значений некоторых признаков с помощью интервалов. Цель: реализовать функцию, которая будет принимать на вход набор признаков для объекта выборки и возвращать прогноз целевой переменной (0 или 1). Например, вы можете просто сложить все признаки и возращать ноль, если сумма отрицательная, а в противном случае единицу. Но наверняка можно придумать лучше!
# Данные уже разделены на набор для обучения, который вы можете использовать как угодно, и тестовый, на котором нужно будет проверить вашу точность. Постарайтесь достичь точности хотя бы 0.6.

# %%
def predict(Xtest: np.array, a) -> np.array:
    b = a*Xtest
    b = np.sum(b, axis = 1)
    b = b[:, np.newaxis]
    c = b > 0.5
    return c.astype(int)

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
X = data.drop('credit_risk', 1).values
y = data['credit_risk'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=10)

x = 0
while x < 0.8:
    a = np.random.uniform(low=-1, high=1, size=(10, ))
    b = b * X_train
    b = np.sum(b, axis = 1)[:, np.newaxis]
    c = b > 0.5
    c.astype(int)
    d = y_train[:, np.newaxis]
    e = c - d
    x = np.size(e[e == 0])/np.size(e)

accuracy_score(y_test, predict(X_test, a))
# Out:
# C:\Users\днс\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   # Remove the CWD from sys.path while we load stuff.
